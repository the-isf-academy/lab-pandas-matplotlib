# %% [markdown]
# # Data Exploration
# In this notebook, explore the data from the technology use survey we designed and sent out to the school.
#
# Use Pandas and Matplotlib to help with your exploration.

# %%
# Import Pandas Library
import pandas as pd

# Import Matplotlib 
import matplotlib.pyplot as plt

# %%
# save path of csv file 
survey_responses_path = "data_files/survey_responses_cleaned.csv"

# create dataframe from csv file
responses_df = pd.read_csv(survey_responses_path)

# %%
responses_df.head()
# Out:
#            timestamp  grade  gender  num_courses  num_cca  \
# 0  2/1/2021 11:08:43      7  Female          NaN      NaN
# 1  2/1/2021 11:10:27      7  Female          NaN      3.0
# 2  2/1/2021 11:11:28      9  Female          8.0      1.0
# 3  2/1/2021 11:13:16      7    Male         10.0      4.0
# 4  2/1/2021 11:14:56      6    Toad         12.0      3.0
#
#    num_homework_hours_per_day  num_after_school_activities_per_week  \
# 0                         3.0                                   5.0
# 1                         2.5                                   1.0
# 2                         1.5                                   8.0
# 3                         2.5                                   2.0
# 4                         0.0                                   2.0
#
#   parental_controls_enabled parental_controls_app_restrictions_enabled  \
# 0                      True                                       True
# ...
