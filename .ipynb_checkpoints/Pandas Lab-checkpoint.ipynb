# %% [markdown]
# ## Introduction

# %% [markdown]
# Overview of Sections:
#
# **Part 1: Pandas**
# In this section we will learn how to create Pandas dataframes and how to filter them to find specific subsets of your data
#
# **Part 2: Matplotlib**
# In this section we will learn how to create Basic Matplotlib plots to visualize data that we're interested in
#
# **Part 3: Pokemon!**
# In this section we will take what we've learned in sections 1 and 2 and apply them to a dataset in order to make the ULTIMATE DECK.

# %% [markdown]
# ## Part 1: Pandas

# %% [markdown]
# ### Intro

# %% [markdown]
# ![Screen%20Shot%202020-11-13%20at%208.01.06%20AM.png](attachment:Screen%20Shot%202020-11-13%20at%208.01.06%20AM.png)

# %% [markdown]
# The **Pandas Library** is a fast, powerful, flexible library used for data analysis and manipulation.

# %%
#Start by importing it
import pandas as pd

# %% [markdown]
# ### The DataFrame

# %% [markdown]
# ![Screen%20Shot%202020-11-12%20at%2011.05.43%20AM.png](attachment:Screen%20Shot%202020-11-12%20at%2011.05.43%20AM.png)

# %% [markdown]
# Pandas is built around a data structure called a "Dataframe". Its basically just a table.

# %%
#Pandas defines its DataFrame variable as a dictionary of lists...

dataframe_1 = pd.DataFrame(
    {"Column 1": ["Cell 1", "Cell 3"],
     "Column 2": ["Cell 2", "Cell 4"]
     }
)

dataframe_1

# %% [markdown]
# #### Exercise

# %% [markdown]
# Based on the previous cell - define and display a Pandas Dataframe that looks like this ![Screen%20Shot%202020-11-13%20at%207.31.34%20AM.png](attachment:Screen%20Shot%202020-11-13%20at%207.31.34%20AM.png)

# %%
#Write your code here:

# %% [markdown]
# ### Importing

# %% [markdown]
# ![Screen%20Shot%202021-02-01%20at%2010.13.40%20AM.png](attachment:Screen%20Shot%202021-02-01%20at%2010.13.40%20AM.png)

# %% [markdown]
# The Pandas "read_csv" function takes a path input and returns a Pandas Dataframe.
#
# Why is the does the path have "data_files/" before the name of the file?

# %%
movie_path = "data_files/movie_scores.csv"
movie_df = pd.read_csv(movie_path)

# %% [markdown]
# To display only the first 5 rows lets use the pandas function ".head()"

# %%
movie_df.head()

# %% [markdown]
# To view a different number of rows use integers as an arguement

# %%
movie_df.head(2)

# %% [markdown]
# ### Choosing columns

# %% [markdown]
# To look at specific columns we use the the syntax: dataframe[["column_1","column_2","column_n"]]

# %%
RT_rating_only = movie_df[["FILM","RottenTomatoes"]]
RT_rating_only.head(5)

# %% [markdown]
# #### Exercise: Create a dataframe that looks like this ![Screen%20Shot%202020-11-16%20at%2011.01.12%20AM.png](attachment:Screen%20Shot%202020-11-16%20at%2011.01.12%20AM.png)

# %%
# Write your code here

# %% [markdown]
# To export use the "to_csv" function on a Dataframe and specify what the file should be named as an input

# %%
RT_rating_only.to_csv(r'rotten_data.csv')

# %% [markdown]
# Now check your directory! Is there a new file?

# %% [markdown]
# ### Filtering

# %% [markdown]
# ![Screen%20Shot%202020-11-12%20at%2011.06.26%20AM.png](attachment:Screen%20Shot%202020-11-12%20at%2011.06.26%20AM.png)

# %% [markdown]
# To filter we use the loc and iloc functions
#
# Lets start by setting the "FILM" column as our index

# %%
movie_df = movie_df.set_index("FILM")
movie_df.head()

# %% [markdown]
# Now we can grab specific values with the operation .loc

# %%
movie_df.loc["Ant-Man (2015)", "Metacritic"]

# %%
movie_df.loc["Do You Believe? (2015)", "Fandango_Stars"]

# %% [markdown]
# #### Exercise: Find the Rotten Tomatoes score for "Top Five (2014)" using iloc

# %%
# Write your code here

# %% [markdown]
# To go one step further we can add conditionals to loc and iloc operations using this syntax

# %%
movie_df.loc[(movie_df["RottenTomatoes"] == 100)]

# %% [markdown]
# ...or multiple conditionals using this syntax for "or"

# %%
movie_df.loc[(movie_df["RottenTomatoes"] == 100) | (
    movie_df["Metacritic"] == 94),:]

# %% [markdown]
# ...and this syntax for "and"

# %%
movie_df.loc[(movie_df["RottenTomatoes"] == 100)].loc[(movie_df["Metacritic"] == 90)]

# %% [markdown]
# #### Exercise: Output a list of movies that got greater than 98 on Rotten Tomatoes and greater than 90 on Metacritic

# %%
#Write your code here:

# %% [markdown]
# ### Sorting

# %% [markdown]
# To sort we use "sort_values()" with the column name as input

# %%
movie_df.sort_values("RottenTomatoes").head()

# %% [markdown]
# To sort in descending order add this

# %%
movie_df.sort_values("RottenTomatoes", ascending=False).head(10)

# %% [markdown]
# We can also sort by multiple columns

# %%
movie_df.sort_values(["RottenTomatoes", "Metacritic"], ascending=False).head(10)

# %% [markdown]
# ### Summary Functions (Max, Min, Mean, Count, Sum)

# %% [markdown]
# These are pretty straight forward - take a look and be ready to use them in Part 4
#
# .max() will give you the maximum value in a column

# %%
movie_df["RottenTomatoes"].max()

# %% [markdown]
# .min() will give you the minimum value in a column

# %%
movie_df["RottenTomatoes"].min()

# %%
movie_df["RottenTomatoes"].mean()

# %% [markdown]
# .count() will give you the number of cells in a column

# %%
movie_df["RottenTomatoes"].count()

# %% [markdown]
# .sum() will give you the number of cells in a column

# %%
movie_df["RottenTomatoes"].sum()

# %% [markdown]
# These functions can be chained to things that you already know!
#
# Examples:

# %% [markdown]
# ![Screen%20Shot%202021-02-01%20at%2010.24.03%20AM.png](attachment:Screen%20Shot%202021-02-01%20at%2010.24.03%20AM.png)

# %%
movie_df.loc[(movie_df["RottenTomatoes"]<80)].loc[(movie_df["Fandango_Stars"]<4)]["Metacritic"].max()

# %% [markdown]
# #### Exercise: What is the mean Rotten Tomatoes score for movies with a Metacritic score of over 85?

# %%
#Write your code here:

# %% [markdown]
# ## Part 2: Matplotlib

# %% [markdown]
# ### Intro

# %% [markdown]
# Filtering data is useful - but its not the whole picture!
#
# In this Matplotlib section we will cover how to visualize data in a number of ways

# %% [markdown]
# Lets start by importing everything we need...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Line plots

# %% [markdown]
# Now we'll take a look at the basic plot function - without a full explanation - can you explain what's happening here?
#
# What does the plot function do? What inputs does it take?

# %%
plt.plot([1,2,3],[3,2,1])

# %% [markdown]
# Write the code for a plot that looks like this

# %% [markdown]
# <img src="Screen%20Shot%202021-02-01%20at%2010.43.47%20AM.png" alt="Drawing" style="width: 400px;"/>

# %%
#Write your code here

# %% [markdown]
# ### Box plots

# %% [markdown]
# Lets go back to our movie data!

# %%
movie_df.head()
# Out:
#                              FILM  RottenTomatoes  Metacritic  IMDB  \
# 0  Avengers: Age of Ultron (2015)              74          66   7.8
# 1               Cinderella (2015)              85          67   7.1
# 2                  Ant-Man (2015)              80          64   7.8
# 3          Do You Believe? (2015)              18          22   5.4
# 4   Hot Tub Time Machine 2 (2015)              14          29   5.1
#
#    Fandango_Stars
# 0             5.0
# 1             5.0
# 2             5.0
# 3             5.0
# 4             3.5

# %%
first_five_movies = movie_df.head()

# %%
plt.bar(first_five_movies["FILM"],first_five_movies["RottenTomatoes"])
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# #### Exercise: Create the same barchart but for Metacritic instead of RottenTomatoes?

# %%
#Write your code here

# %% [markdown]
# ### Scatter plots

# %% [markdown]
# Now lets look at some movie data on a scatter plot!

# %%
plt.scatter(first_five_movies["Metacritic"],first_five_movies["RottenTomatoes"])

# %% [markdown]
# ... Or we can look at the whole dataset!

# %%
plt.scatter(movie_df["Metacritic"],movie_df["RottenTomatoes"])

# %% [markdown]
# What does this tell us about Metacritic and RottenTomatoes?

# %% [markdown]
# ## Part 3: Application with a Pokemon Dataset

# %% [markdown]
# ![Screen%20Shot%202020-11-13%20at%208.10.01%20AM.png](attachment:Screen%20Shot%202020-11-13%20at%208.10.01%20AM.png)

# %% [markdown]
# You made it!
#
# We've now covered all of the Pandas skills that you'll be learning today so its time to practice.
#
# And what better way...
#
# than with an awesome Pokemon dataset.

# %% [markdown]
# **TIP: COPY AND PASTE is your friend.** Don't try and remember everything - just copy and paste from Parts 1 + 2

# %%
# Start by filling in the path to the Pokemon data file
pokemon = ""

# %%
# Now read the file with pd.read_csv(path)
pokemon_df = 
pokemon_df.head()

# %% [markdown]
# **Question 1**: Create a new dataframe with only the following columns - "Name, Type 1, Type 2, Total"

# %%
# Write your code here

# %% [markdown]
# **Question 2**: What Pokemon has the greatest total?

# %%
# Write your code here

# %% [markdown]
# **Question 3**: Go back to the dataset with all columns. What are the top 5 most powerful legendary pokemon?

# %%
# Write your code here

# %% [markdown]
# **Question 4**: List the five Generation 6 Pokemon that have the least HP.

# %%
# Write your code here

# %% [markdown]
# **Question 5**: How many Type 1 "Normal" Pokemon become Type 2 "Flying"?

# %%
# Write your code here

# %% [markdown]
# **Question 6**: Use your own logic/preferences to create a deck of 5 pokemon. You can only have 1 Legendary, you have to have at least 3 Types, and the sum of your generations can't be greater than 16.

# %%
# Write your code here

# %% [markdown]
# **Question 7:** Create a line plot of attack power for all the evolutions of charmander

# %%
# Write your code here

# %% [markdown]
# **Question 8:** Create a box plot of all of bulbasaurs columns

# %%
# Write your code here

# %% [markdown]
# **Question 9:** Create a scatter plot comparing HP from water pokemon vs fire pokemon

# %%
# Write your code here
